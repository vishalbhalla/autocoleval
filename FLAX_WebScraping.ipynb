# %% [markdown]
# ## Web Scraping - FLAX

# %%
from bs4 import BeautifulSoup, NavigableString
# from urllib2 import urlopen
from urllib.request import urlopen

import requests
from lxml import html
from xml.etree import cElementTree as ET

import xml, json
import pandas as pd

import os
import time
from time import gmtime, strftime

import spacy
nlp = spacy.load('en_core_web_lg')

import itertools
from operator import itemgetter
from itertools import groupby
from pprint import pprint

# %%
# Download all the files in the 'code' folder and place it in the present working directory
# %cd r'D:\Education\vocabexpert\acl_bea_paper\code'
# %pwd

# %%
if not os.path.isdir('./pattern'):
    # !git clone 'https://github.com/clips/pattern.git'
    
# Note: Download the pattern folder manually from the development branch of the github link (https://github.com/clips/pattern.git) for Python 3.5+

# %%
# Change path (use full path) to current directory + pattern i.e. where the CLIPS-Pattern repository was cloned.
# MODULE = './pattern'
MODULE = r'D:\Education\vocabexpert\acl_bea_paper\code\pattern'
import sys;
if MODULE not in sys.path: 
    sys.path.append(MODULE)

# os.path.abspath('./pattern/')

# %%
# import os, sys; sys.path.insert(0, os.path.join(os.path.dirname(__file__), "..", ".."))
import os, sys; sys.path.insert(0, os.path.join(os.path.dirname(MODULE), "..", ".."))

from pattern.en import article, referenced
from pattern.en import pluralize, singularize
from pattern.en import comparative, superlative
from pattern.en import conjugate, lemma, lexeme, tenses
from pattern.en import NOUN, VERB, ADJECTIVE, ADVERB

# The en module has a range of tools for word inflection:
# pluralization and singularization, comparative and superlative adjectives, verb conjugation.

# %%
def mapFlaxToClipsPatternsPOSTags(tag):
    if tag == 'n':
        return NOUN
    elif tag in 'v':
        return VERB
    elif tag in 'a':
        return ADJECTIVE
    elif tag in 'r':
        return ADVERB
    else:
        return NOUN

# %%
def getClipsPatterns(lemma, posTag):
    words = []
    
    clipsPOSTag = mapFlaxToClipsPatternsPOSTags(posTag)
        
    # VERB CONJUGATION
    if clipsPOSTag == VERB:        
        words = lexeme(lemma)
        # words = conjugate(lemma)
        # words = tenses(lemma)
        
    elif clipsPOSTag == ADJECTIVE:
        words.append(lemma)
        wc = comparative(lemma)
        words.append(wc)
        ws = superlative(lemma)
        words.append(ws)
        
    else:
        # Lemma form
        words.append(lemma)
    
        # PLURALIZATION
        w = pluralize(lemma, pos=clipsPOSTag)
        words.append(w)
    
    return words

# %%
def mapSpacyFlaxPOSTags(tag):
    if tag in ['NN', 'NNS', 'NNP', 'NNPS']:
        return 'n'
        
    elif tag in ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']:
        return 'v'
    
    elif tag in ['JJ', 'JJR', 'JJS']:
        return 'a'
    
    elif tag in ['RB', 'RBR', 'RBS']:
        return 'r'
    
    else:
        return tag

# %%
def getWordForms(lemma, posTag):
    lstWordForms = []
    words = getClipsPatterns(lemma, posTag)
    for word in words:
        lstWordForms.append((lemma, word))
    
    return lstWordForms

# %%
def getFlaxCollocations(lemma, posTag, colType, colPosTag):

    lstFlaxCols = []
    lstFlaxColsLemPosCollocates = []
    lstFlaxColChecked = []
    lstFlaxColFiltered = []
    lstWordForms = getWordForms(lemma, posTag)
    colTypeQuery = colType.split('-')[1]
    
    # URL to get the requests
    strBaseURL = 'http://flax.nzdl.org/greenstone3/flax?a=pr&rt=r&ro=1&o=xml&c=collocations&s=CollocationSampleRetrieve&s1.dbName=BAWE&s1.colloType='
    query = '&s1.query='
    wordTag = '&s1.wordType='
    
    for word in lstWordForms:
        requestUrl = strBaseURL + colTypeQuery + query + word[1] + wordTag + posTag
        with requests.Session() as session:
            r = session.get(requestUrl)
            respObj = r.text
            respObj = ET.fromstring(respObj)
            for data in respObj.getiterator('collo'):
#                 print(data.get('word'), data.get('colloType'), data.find('text').text, data.get('fre'))
                strCollocates = data.find('text').text
                lstCollocates = strCollocates.split(' ')
                lstFlaxCols.append((lemma, data.get('word'), posTag, strCollocates, data.get('colloType'), data.get('fre')))
                
                collocate = ''
                for w in lstCollocates:
                    if w != word[1]:
                        collocate += w
                        collocate += ' '
                
                strCollocates = collocate.strip()
                
                collocates = ()
                colFiltered = ('', '')
                i = 0
                doc = nlp(strCollocates)
                match = False
                for token in doc:
                    collocates += (token.lemma_, token, token.tag_)
                    tag = token.tag_
                    tagFL = mapSpacyFlaxPOSTags(tag)
                    if tagFL == colPosTag:
                        colFiltered = (token.lemma_, tagFL)
                        match = True
                    i+=1
                
                while i < 5:
                    collocates += ('', '', '')
                    i+=1
                
                if match ==  False:
                    collocateNoMatchLemma = ''
                    collocateNoMatchTag = ''
                    for token in doc:                    
                        tag = token.tag_
                        tagFL = mapSpacyFlaxPOSTags(tag)
                        collocateNoMatchLemma += token.lemma_ + ' '
                        collocateNoMatchTag += tagFL + ' '

                    collocateNoMatchLemma = collocateNoMatchLemma.strip()
                    collocateNoMatchTag = collocateNoMatchTag.strip()
                    colFiltered = (collocateNoMatchLemma, collocateNoMatchTag)

                
                lstFlaxColsLemPosCollocates.append((lemma, data.get('word'), posTag, collocates[0], collocates[1], collocates[2], 
                                                    collocates[3], collocates[4], collocates[5], collocates[6], collocates[7], 
                                                    collocates[8], collocates[9], collocates[10], collocates[11], collocates[12], 
                                                    collocates[13], collocates[14], data.get('colloType'), data.get('fre')))
                
                lstFlaxColChecked.append((lemma, posTag, colFiltered[0], colFiltered[1], data.get('colloType'), int(data.get('fre'))))
                

    grouper = itemgetter(0,1,2,3,4)
    lstFlaxColFiltered = []
    for key, grp in groupby(sorted(lstFlaxColChecked, key = grouper), grouper):
        temp_dict = dict(zip([0,1,2,3,4], key))
        temp_dict[5] = sum(item[5] for item in grp)
        vals = tuple(temp_dict.values())
        lstFlaxColFiltered.append(vals)
        
    lstFlaxColFiltered = sorted(lstFlaxColFiltered, key=lambda x: x[5], reverse=True)
               
    return lstFlaxCols, lstFlaxColsLemPosCollocates, lstFlaxColFiltered

# %%
# Change path to the folder where all collocation data files will be stored
colFolder = r'D:\Education\vocabexpert\acl_bea_paper\eval\collocations\flax' 

# Change path to the folder where all reference files are stored. 
# Basically, this folder should then have 2 folders of 'se_flax' and 'elia' which contain the reference files.
# %cd D:\Education\vocabexpert\acl_bea_paper\eval\reference
# %pwd
# Out:
# D:\Education\vocabexpert\acl_bea_paper\eval\reference
# 'D:\\Education\\vocabexpert\\acl_bea_paper\\eval\\reference'

# %%
def getWordList(wordListCSVFile):
    colNameWord = 'Headword'
    colNamePOS = 'POS'
    df = pd.read_csv(wordListCSVFile)
    
    words = df[colNameWord].tolist()
    posTags = df[colNamePOS].tolist()
    
    wordList = list(zip(words, posTags))
    
    wordList = list(set(wordList))
    
    wordList = sorted(wordList)
    
    return wordList

# %%
lstRefColTypesFileNames = ['n1_n2', 'n2_n1', 'n2_v1', 'n2_adj1', 'v1_n2', 'v1_adj2', 'v1_adv2', 
                           'v2_adv1', 'adj1_n2', 'adj2_v1', 'adj2_adv1']
lstRefColTypesFLAX = ['n-nn', 'n-nn', 'n-vn', 'n-an', 'v-vn', 'v-vppa', 'v-vr', 'v-rv', 'a-an', 'a-vppa', 'a-ra']
lstRefColPosTag = ['n', 'n', 'v', 'a', 'n', 'a', 'r', 'r', 'n', 'v', 'r']

# %%
print(strftime("%Y-%m-%d %H:%M:%S", gmtime()))

for i in range(11): # Use time delay (sleep) as there is a limit on the number of hits.
#     i = 0
    colTypeFileName = lstRefColTypesFileNames[i]
    colType = lstRefColTypesFLAX[i]
    colPosTag = lstRefColPosTag[i]
    
    wordListCSVFile = './se_flax/ACL - Reference set - ' + colTypeFileName + '.csv'
    lstWords = getWordList(wordListCSVFile) #Read from word list
    print(colTypeFileName + ' : ' , str(len(lstWords)))
    
    colFlax = os.path.join(colFolder, colTypeFileName)
    
    for word in lstWords:
        print(word)
        lemma = word[0].lower()
        posTag = word[1]
        if posTag == 'adj':
            posTag = 'a'
        
#         print(lemma, posTag, colType)
        lstFlaxCols, lstFlaxColsLemPosCollocates, lstFlaxColFiltered = getFlaxCollocations(lemma, posTag, colType, colPosTag)
        
        if len(lstFlaxCols) != 0:
            
            final_directory = colFlax
            if not os.path.exists(final_directory):
                os.makedirs(final_directory)
            fname = final_directory + '/' + lemma + '_' + posTag + '_' + 'Raw' + '_' + colTypeFileName + '+' + colType + '.csv'
            
            headers = ['HeadWord_Lemma', 'HeadWord_Form', 'HeadWord_Lempos', 'Collocate_Words', 'Collo_Type', 'Frequency']
            df = pd.DataFrame(lstFlaxCols, columns=headers)
            df.to_csv(fname, index=False)
            
            
            fname = final_directory + '/' + lemma + '_' + posTag + '_' + 'ColWordsLemPos' + '_' + colTypeFileName + '+' + colType + '.csv'
            
            headersColLemPos = ['HeadWord_Lemma', 'HeadWord_Form', 'HeadWord_Lempos', 'ColWord_Lemma1', 'ColWord1', 'ColWord_Lempos1', 
                                'ColWord_Lemma2', 'ColWord2', 'ColWord_Lempos2', 'ColWord_Lemma3', 'ColWord3', 'ColWord_Lempos3', 
                                'ColWord_Lemma4', 'ColWord4', 'ColWord_Lempos4', 'ColWord_Lemma5', 'ColWord5', 'ColWord_Lempos5', 
                                'Collo_Type', 'Frequency']
            df = pd.DataFrame(lstFlaxColsLemPosCollocates, columns=headersColLemPos)
            df.to_csv(fname, index=False)
            
            
            fname = final_directory + '/' + lemma + '_' + posTag + '_' + 'ColWordsFiltered' + '_' + colTypeFileName + '+' + colType + '.csv'
            headersColFiltered = ['HeadWord_Lemma', 'HeadWord_Lempos', 'ColWord_Lemma', 'ColWord_Lempos', 'Collo_Type', 'Frequency']
            df = pd.DataFrame(lstFlaxColFiltered, columns=headersColFiltered)
            df.to_csv(fname, index=False)

        else:
            print('This word doesnt have any collocation type generated! - ' + str(i) + ' ' + lemma + '_' + posTag + '_' + colTypeFileName + '+' + colType)

print(strftime("%Y-%m-%d %H:%M:%S", gmtime()))
# Out:
# 2018-04-26 12:48:39
# n1_n2 :  39
# ('assessment', 'n')
# ('background', 'n')
# ('business', 'n')
# ('career', 'n')
# ('class', 'n')
# ('climate', 'n')
# ('conflict', 'n')
# ('data', 'n')
# ('employment', 'n')
# ('expert', 'n')
# ('field', 'n')
# ('gender', 'n')
# ('government', 'n')
# ('information', 'n')
# ('internet', 'n')
# ('learning', 'n')
# ('medium', 'n')
# ('minority', 'n')
# ('opinion', 'n')
# ('party', 'n')
# ('peace', 'n')
# ('pilot', 'n')
# ('planning', 'n')
# ('problem', 'n')
# ('research', 'n')
# ('risk', 'n')
# ('security', 'n')
# ('service', 'n')
# ('source', 'n')
# ('state', 'n')
# ('stress', 'n')
# ('survey', 'n')
# ('target', 'n')
# ('teaching', 'n')
# ('test', 'n')
# ('thinking', 'n')
# ('thought', 'n')
# ('transport', 'n')
# ('welfare', 'n')
# n2_n1 :  52
# ('access', 'n')
# ('area', 'n')
# ('assessment', 'n')
# ('audience', 'n')
# ('change', 'n')
# ('consciousness', 'n')
# ('control', 'n')
# ('coverage', 'n')
# ('data', 'n')
# ('department', 'n')
# ('development', 'n')
# ('difficulty', 'n')
# ('effort', 'n')
# ('environment', 'n')
# ('equality', 'n')
# ('evidence', 'n')
# ('expenditure', 'n')
# ('finding', 'n')
# ('flow', 'n')
# ('gathering', 'n')
# ('group', 'n')
# ('intervention', 'n')
# ('knowledge', 'n')
# ('leader', 'n')
# ('level', 'n')
# ('material', 'n')
# ('methodology', 'n')
# ('objective', 'n')
# ('opinion', 'n')
# ('opportunity', 'n')
# ('outcome', 'n')
# ('policy', 'n')
# ('process', 'n')
# ('processing', 'n')
# ('purpose', 'n')
# ('reform', 'n')
# ('research', 'n')
# ('resolution', 'n')
# ('resource', 'n')
# ('retrieval', 'n')
# ('score', 'n')
# ('sector', 'n')
# ('set', 'n')
# ('sharing', 'n')
# ('stage', 'n')
# ('stereotype', 'n')
# ('strategy', 'n')
# ('study', 'n')
# ('system', 'n')
# ('topic', 'n')
# ('transaction', 'n')
# ('treaty', 'n')
# n2_v1 :  156
# ('access', 'n')
# ('activity', 'n')
# ('adjustment', 'n')
# ('agenda', 'n')
# ('agreement', 'n')
# ('alternative', 'n')
# ('analysis', 'n')
# ('approach', 'n')
# ('area', 'n')
# ('argument', 'n')
# ('arrangement', 'n')
# ('article', 'n')
# ('aspect', 'n')
# ('assessment', 'n')
# ('assistance', 'n')
# ('assumption', 'n')
# ('attention', 'n')
# ('attitude', 'n')
# ('authority', 'n')
# ('awareness', 'n')
# ('benefit', 'n')
# ('care', 'n')
# ('category', 'n')
# ('challenge', 'n')
# ('clue', 'n')
# ('comment', 'n')
# ('competence', 'n')
# ('concept', 'n')
# ('conclusion', 'n')
# ('condition', 'n')
# ('conference', 'n')
# ('conflict', 'n')
# ('consensus', 'n')
# ('consent', 'n')
# ('consequence', 'n')
# ('consideration', 'n')
# ('constraint', 'n')
# ('contact', 'n')
# ('context', 'n')
# ('contribution', 'n')
# ('coverage', 'n')
# ('crime', 'n')
# ('criterion', 'n')
# ('data', 'n')
# ('definition', 'n')
# ('development', 'n')
# ('difficulty', 'n')
# ('dilemma', 'n')
# ('discrimination', 'n')
# ('dispute', 'n')
# ('distinction', 'n')
# ('doubt', 'n')
# ('element', 'n')
# ('emission', 'n')
# ('emphasis', 'n')
# ('environment', 'n')
# ('equality', 'n')
# ('error', 'n')
# ('evidence', 'n')
# ('example', 'n')
# ('expectation', 'n')
# ('explanation', 'n')
# ('factor', 'n')
# ('feature', 'n')
# ('feedback', 'n')
# ('finding', 'n')
# ('focus', 'n')
# ('format', 'n')
# ('foundation', 'n')
# ('function', 'n')
# ('goal', 'n')
# ('guidance', 'n')
# ('help', 'n')
# ('illustration', 'n')
# ('impact', 'n')
# ('implication', 'n')
# ('impression', 'n')
# ('indication', 'n')
# ('information', 'n')
# ('initiative', 'n')
# ('insight', 'n')
# ('instruction', 'n')
# ('interview', 'n')
# ('issue', 'n')
# ('journal', 'n')
# ('judgement', 'n')
# ('knowledge', 'n')
# ('learning', 'n')
# ('legislation', 'n')
# ('likelihood', 'n')
# ('limitation', 'n')
# ('line', 'n')
# ('living', 'n')
# ('material', 'n')
# ('meaning', 'n')
# ('message', 'n')
# ('method', 'n')
# ('methodology', 'n')
# ('objective', 'n')
# ('obligation', 'n')
# ('observation', 'n')
# ('offence', 'n')
# ('opportunity', 'n')
# ('outcome', 'n')
# ('overview', 'n')
# ('parameter', 'n')
# ('peak', 'n')
# ('performance', 'n')
# ('policy', 'n')
# ('possibility', 'n')
# ('potential', 'n')
# ('precedence', 'n')
# ('prediction', 'n')
# ('presentation', 'n')
# ('priority', 'n')
# ('problem', 'n')
# ('procedure', 'n')
# ('process', 'n')
# ('provision', 'n')
# ('question', 'n')
# ('range', 'n')
# ('recommendation', 'n')
# ('relationship', 'n')
# ('report', 'n')
# ('requirement', 'n')
# ('research', 'n')
# ('resemblance', 'n')
# ('resource', 'n')
# ('responsibility', 'n')
# ('restriction', 'n')
# ('result', 'n')
# ('role', 'n')
# ('service', 'n')
# ('source', 'n')
# ('statement', 'n')
# ('statistic', 'n')
# ('strategy', 'n')
# ('stress', 'n')
# ('study', 'n')
# ('summary', 'n')
# ('support', 'n')
# ('survey', 'n')
# ('target', 'n')
# ('task', 'n')
# ('technique', 'n')
# ('tendency', 'n')
# ('theory', 'n')
# ('threat', 'n')
# ('topic', 'n')
# ('transition', 'n')
# ('treatment', 'n')
# ('treaty', 'n')
# ('trend', 'n')
# ('variation', 'n')
# ('way', 'n')
# ('work', 'n')
# n2_adj1 :  483
# ('ability', 'n')
# ('abuse', 'n')
# ('acceptance', 'n')
# ('access', 'n')
# ('account', 'n')
# ('accuracy', 'n')
# ('achievement', 'n')
# ('act', 'n')
# ('action', 'n')
# ('activism', 'n')
# ('activity', 'n')
# ('adjustment', 'n')
# ('administration', 'n')
# ('advance', 'n')
# ('advantage', 'n')
# ('affair', 'n')
# ('agency', 'n')
# ('agenda', 'n')
# ('agreement', 'n')
# ('aim', 'n')
# ('amount', 'n')
# ('analysis', 'n')
# ('ancestor', 'n')
# ('answer', 'n')
# ('appearance', 'n')
# ('approach', 'n')
# ('area', 'n')
# ('arena', 'n')
# ('argument', 'n')
# ('arrangement', 'n')
# ('array', 'n')
# ('aspect', 'n')
# ('assessment', 'n')
# ('assistance', 'n')
# ('assumption', 'n')
# ('attempt', 'n')
# ('attention', 'n')
# ('attitude', 'n')
# ('audience', 'n')
# ('author', 'n')
# ('authority', 'n')
# ('autonomy', 'n')
# ('average', 'n')
# ('awareness', 'n')
# ('background', 'n')
# ('basis', 'n')
# ('behaviour', 'n')
# ('belief', 'n')
# ('benefit', 'n')
# ('body', 'n')
# ('bond', 'n')
# ('boundary', 'n')
# ('capacity', 'n')
# ('capitalism', 'n')
# ('care', 'n')
# ('career', 'n')
# ('case', 'n')
# ('category', 'n')
# ('cause', 'n')
# ('centre', 'n')
# ('challenge', 'n')
# ('change', 'n')
# ('chapter', 'n')
# ('characteristic', 'n')
# ('choice', 'n')
# ('circle', 'n')
# ('circumstance', 'n')
# ('class', 'n')
# ('climate', 'n')
# ('colleague', 'n')
# ('comment', 'n')
# ('communication', 'n')
# ('community', 'n')
# ('competition', 'n')
# ('complexity', 'n')
# ('component', 'n')
# ('concentration', 'n')
# ('concept', 'n')
# ('concern', 'n')
# ('conclusion', 'n')
# ('condition', 'n')
# ('conference', 'n')
# ('conflict', 'n')
# ('connotation', 'n')
# ('consciousness', 'n')
# ('consensus', 'n')
# ('consent', 'n')
# ('consequence', 'n')
# ('consideration', 'n')
# ('construct', 'n')
# ('contact', 'n')
# ('context', 'n')
# ('contrast', 'n')
# ('contribution', 'n')
# ('control', 'n')
# ('core', 'n')
# ('correlation', 'n')
# ('cost', 'n')
# ('country', 'n')
# ('crisis', 'n')
# ('criterion', 'n')
# ('critique', 'n')
# ('culture', 'n')
# ('currency', 'n')
# ('customer', 'n')
# ('damage', 'n')
# ('data', 'n')
# ('database', 'n')
# ('death', 'n')
# ('debate', 'n')
# ('decade', 'n')
# ('decision', 'n')
# ('definition', 'n')
# ('degradation', 'n')
# ('degree', 'n')
# ('demand', 'n')
# ('democracy', 'n')
# ('description', 'n')
# ('design', 'n')
# ('detail', 'n')
# ('development', 'n')
# ('difference', 'n')
# ('difficulty', 'n')
# ('dilemma', 'n')
# ('dimension', 'n')
# ('disaster', 'n')
# ('discipline', 'n')
# ('discourse', 'n')
# ('discrimination', 'n')
# ('discussion', 'n')
# ('display', 'n')
# ('distinction', 'n')
# ('distribution', 'n')
# ('diversity', 'n')
# ('domain', 'n')
# ('dominance', 'n')
# ('draft', 'n')
# ('duration', 'n')
# ('economy', 'n')
# ('edition', 'n')
# ('education', 'n')
# ('effect', 'n')
# ('effort', 'n')
# ('election', 'n')
# ('element', 'n')
# ('emphasis', 'n')
# ('employment', 'n')
# ('encounter', 'n')
# ('energy', 'n')
# ('entity', 'n')
# ('environment', 'n')
# ('equality', 'n')
# ('equilibrium', 'n')
# ('error', 'n')
# ('essay', 'n')
# ('evaluation', 'n')
# ('event', 'n')
# ('evidence', 'n')
# ('evolution', 'n')
# ('examination', 'n')
# ('example', 'n')
# ('exception', 'n')
# ('exclusion', 'n')
# ('existence', 'n')
# ('expansion', 'n')
# ('expectation', 'n')
# ('expenditure', 'n')
# ('experience', 'n')
# ('expertise', 'n')
# ('explanation', 'n')
# ('exploitation', 'n')
# ('expression', 'n')
# ('extent', 'n')
# ('factor', 'n')
# ('faith', 'n')
# ('family', 'n')
# ('feature', 'n')
# ('feedback', 'n')
# ('figure', 'n')
# ('finding', 'n')
# ('flexibility', 'n')
# ('focus', 'n')
# ('force', 'n')
# ('form', 'n')
# ('format', 'n')
# ('formula', 'n')
# ('fraction', 'n')
# ('framework', 'n')
# ('freedom', 'n')
# ('frequency', 'n')
# ('function', 'n')
# ('fund', 'n')
# ('generation', 'n')
# ('goal', 'n')
# ('good', 'n')
# ('government', 'n')
# ('group', 'n')
# ('growth', 'n')
# ('harm', 'n')
# ('health', 'n')
# ('heritage', 'n')
# ('history', 'n')
# ('identity', 'n')
# ('ideology', 'n')
# ('illness', 'n')
# ('image', 'n')
# ('impact', 'n')
# ('implementation', 'n')
# ('implication', 'n')
# ('importance', 'n')
# ('impression', 'n')
# ('improvement', 'n')
# ('incidence', 'n')
# ('income', 'n')
# ('increase', 'n')
# ('indication', 'n')
# ('individual', 'n')
# ('inequality', 'n')
# ('influence', 'n')
# ('information', 'n')
# ('initiative', 'n')
# ('innovation', 'n')
# ('inquiry', 'n')
# ('insight', 'n')
# ('inspection', 'n')
# ('instability', 'n')
# ('institution', 'n')
# ('integration', 'n')
# ('intelligence', 'n')
# ('intensity', 'n')
# ('intent', 'n')
# ('interaction', 'n')
# ('intercourse', 'n')
# ('interest', 'n')
# ('interpretation', 'n')
# ('intervention', 'n')
# ('introduction', 'n')
# ('investigation', 'n')
# ('investment', 'n')
# ('investor', 'n')
# ('involvement', 'n')
# ('isolation', 'n')
# ('issue', 'n')
# ('item', 'n')
# ('journal', 'n')
# ('knowledge', 'n')
# ('language', 'n')
# ('law', 'n')
# ('leader', 'n')
# ('learning', 'n')
# ('legislation', 'n')
# ('level', 'n')
# ('life', 'n')
# ('likelihood', 'n')
# ('line', 'n')
# ('link', 'n')
# ('literature', 'n')
# ('living', 'n')
# ('location', 'n')
# ('look', 'n')
# ('majority', 'n')
# ('management', 'n')
# ('market', 'n')
# ('marketplace', 'n')
# ('material', 'n')
# ('mean', 'n')
# ('meaning', 'n')
# ('measure', 'n')
# ('measurement', 'n')
# ('medium', 'n')
# ('meeting', 'n')
# ('member', 'n')
# ('memory', 'n')
# ('merit', 'n')
# ('method', 'n')
# ('minority', 'n')
# ('mobility', 'n')
# ('mobilization', 'n')
# ('model', 'n')
# ('movement', 'n')
# ('nation', 'n')
# ('nature', 'n')
# ('need', 'n')
# ('network', 'n')
# ('norm', 'n')
# ('number', 'n')
# ('objective', 'n')
# ('objectivity', 'n')
# ('obligation', 'n')
# ('observation', 'n')
# ('offence', 'n')
# ('opportunity', 'n')
# ('opposition', 'n')
# ('order', 'n')
# ('organ', 'n')
# ('organism', 'n')
# ('organization', 'n')
# ('orientation', 'n')
# ('origin', 'n')
# ('outcome', 'n')
# ('overview', 'n')
# ('panel', 'n')
# ('paradigm', 'n')
# ('paragraph', 'n')
# ('part', 'n')
# ('participant', 'n')
# ('participation', 'n')
# ('party', 'n')
# ('pattern', 'n')
# ('people', 'n')
# ('percentage', 'n')
# ('perception', 'n')
# ('performance', 'n')
# ('period', 'n')
# ('perspective', 'n')
# ('phase', 'n')
# ('phenomenon', 'n')
# ('philosophy', 'n')
# ('picture', 'n')
# ('planning', 'n')
# ('player', 'n')
# ('point', 'n')
# ('policy', 'n')
# ('pollution', 'n')
# ('population', 'n')
# ('portion', 'n')
# ('position', 'n')
# ('potential', 'n')
# ('power', 'n')
# ('practice', 'n')
# ('premise', 'n')
# ('presence', 'n')
# ('presentation', 'n')
# ('press', 'n')
# ('pressure', 'n')
# ('principle', 'n')
# ('priority', 'n')
# ('probability', 'n')
# ('problem', 'n')
# ('proceeding', 'n')
# ('process', 'n')
# ('product', 'n')
# ('production', 'n')
# ('productivity', 'n')
# ('profile', 'n')
# ('programme', 'n')
# ('progress', 'n')
# ('property', 'n')
# ('proportion', 'n')
# ('prospect', 'n')
# ('prosperity', 'n')
# ('protection', 'n')
# ('provision', 'n')
# ('proximity', 'n')
# ('public', 'n')
# ('purpose', 'n')
# ('qualification', 'n')
# ('quality', 'n')
# ('quantity', 'n')
# ('question', 'n')
# ('range', 'n')
# ('rate', 'n')
# ('reaction', 'n')
# ('reality', 'n')
# ('reason', 'n')
# ('recognition', 'n')
# ('record', 'n')
# ('reduction', 'n')
# ('reference', 'n')
# ('reflection', 'n')
# ('reform', 'n')
# ('relation', 'n')
# ('relationship', 'n')
# ('remark', 'n')
# ('report', 'n')
# ('representation', 'n')
# ('requirement', 'n')
# ('research', 'n')
# ('resource', 'n')
# ('response', 'n')
# ('responsibility', 'n')
# ('result', 'n')
# ('review', 'n')
# ('right', 'n')
# ('risk', 'n')
# ('role', 'n')
# ('root', 'n')
# ('rule', 'n')
# ('safety', 'n')
# ('sample', 'n')
# ('science', 'n')
# ('score', 'n')
# ('scrutiny', 'n')
# ('section', 'n')
# ('sector', 'n')
# ('security', 'n')
# ('sense', 'n')
# ('service', 'n')
# ('set', 'n')
# ('setting', 'n')
# ('sex', 'n')
# ('shift', 'n')
# ('side', 'n')
# ('significance', 'n')
# ('situation', 'n')
# ('skill', 'n')
# ('society', 'n')
# ('solution', 'n')
# ('source', 'n')
# ('space', 'n')
# ('speaker', 'n')
# ('specie', 'n')
# ('spectrum', 'n')
# ('sphere', 'n')
# ('stability', 'n')
# ('staff', 'n')
# ('stage', 'n')
# ('standard', 'n')
# ('state', 'n')
# ('statement', 'n')
# ('statistic', 'n')
# ('status', 'n')
# ('step', 'n')
# ('stereotype', 'n')
# ('strategy', 'n')
# ('structure', 'n')
# ('study', 'n')
# ('success', 'n')
# ('summary', 'n')
# ('support', 'n')
# ('survey', 'n')
# ('symptom', 'n')
# ('system', 'n')
# ('task', 'n')
# ('technique', 'n')
# ('technology', 'n')
# ('tendency', 'n')
# ('tenet', 'n')
# ('term', 'n')
# ('test', 'n')
# ('text', 'n')
# ('theme', 'n')
# ('theory', 'n')
# ('thinking', 'n')
# ('thought', 'n')
# ('threat', 'n')
# ('time', 'n')
# ('tool', 'n')
# ('topic', 'n')
# ('trade', 'n')
# ('tradition', 'n')
# ('training', 'n')
# ('transaction', 'n')
# ('transformation', 'n')
# ('transport', 'n')
# ('treatment', 'n')
# ('treaty', 'n')
# ('trend', 'n')
# ('trust', 'n')
# ('turnover', 'n')
# ('type', 'n')
# ('understanding', 'n')
# ('unemployment', 'n')
# ('usage', 'n')
# ('use', 'n')
# ('value', 'n')
# ('variable', 'n')
# ('variation', 'n')
# ('version', 'n')
# ('view', 'n')
# ('village', 'n')
# ('violence', 'n')
# ('wage', 'n')
# ('war', 'n')
# ('way', 'n')
# ('weapon', 'n')
# ('welfare', 'n')
# ('wisdom', 'n')
# ('work', 'n')
# ('worker', 'n')
# ('world', 'n')
# ('writing', 'n')
# ('year', 'n')
# v1_n2 :  107
# ('accept', 'v')
# ('achieve', 'v')
# ('acquire', 'v')
# ('add', 'v')
# ('address', 'v')
# ('adopt', 'v')
# ('affect', 'v')
# ('allocate', 'v')
# ('allow', 'v')
# ('apply', 'v')
# ('assess', 'v')
# ('assume', 'v')
# ('attend', 'v')
# ('bear', 'v')
# ('become', 'v')
# ('begin', 'v')
# ('carry', 'v')
# ('cast', 'v')
# ('cause', 'v')
# ('change', 'v')
# ('collect', 'v')
# ('come', 'v')
# ('commit', 'v')
# ('complete', 'v')
# ('conduct', 'v')
# ('consider', 'v')
# ('contain', 'v')
# ('contribute', 'v')
# ('convey', 'v')
# ('correct', 'v')
# ('cover', 'v')
# ('create', 'v')
# ('deal', 'v')
# ('demonstrate', 'v')
# ('deny', 'v')
# ('describe', 'v')
# ('develop', 'v')
# ('disclose', 'v')
# ('discuss', 'v')
# ('draw', 'v')
# ('employ', 'v')
# ('encounter', 'v')
# ('encourage', 'v')
# ('engage', 'v')
# ('enhance', 'v')
# ('establish', 'v')
# ('examine', 'v')
# ('exercise', 'v')
# ('experience', 'v')
# ('explore', 'v')
# ('extract', 'v')
# ('face', 'v')
# ('facilitate', 'v')
# ('fall', 'v')
# ('find', 'v')
# ('focus', 'v')
# ('follow', 'v')
# ('fulfil', 'v')
# ('gain', 'v')
# ('gather', 'v')
# ('give', 'v')
# ('have', 'v')
# ('hold', 'v')
# ('identify', 'v')
# ('impose', 'v')
# ('increase', 'v')
# ('interpret', 'v')
# ('introduce', 'v')
# ('lead', 'v')
# ('maintain', 'v')
# ('make', 'v')
# ('meet', 'v')
# ('obtain', 'v')
# ('offer', 'v')
# ('perform', 'v')
# ('place', 'v')
# ('play', 'v')
# ('pose', 'v')
# ('present', 'v')
# ('process', 'v')
# ('promote', 'v')
# ('provide', 'v')
# ('publish', 'v')
# ('raise', 'v')
# ('reach', 'v')
# ('receive', 'v')
# ('record', 'v')
# ('reduce', 'v')
# ('report', 'v')
# ('require', 'v')
# ('resolve', 'v')
# ('review', 'v')
# ('seek', 'v')
# ('serve', 'v')
# ('set', 'v')
# ('share', 'v')
# ('shift', 'v')
# ('show', 'v')
# ('sign', 'v')
# ('start', 'v')
# ('store', 'v')
# ('support', 'v')
# ('take', 'v')
# ('test', 'v')
# ('transmit', 'v')
# ('undertake', 'v')
# ('use', 'v')
# v1_adj2 :  8
# ('become', 'v')
# This word doesnt have any collocation type generated! - 5 become_v_v1_adj2+v-vppa
# ('consider', 'v')
# ('deem', 'v')
# ('get', 'v')
# ('make', 'v')
# ('prove', 'v')
# ('remain', 'v')
# This word doesnt have any collocation type generated! - 5 remain_v_v1_adj2+v-vppa
# ('seem', 'v')
# This word doesnt have any collocation type generated! - 5 seem_v_v1_adj2+v-vppa
# v1_adv2 :  19
# ('apply', 'v')
# ('behave', 'v')
# ('change', 'v')
# ('communicate', 'v')
# ('contribute', 'v')
# ('differ', 'v')
# ('expand', 'v')
# ('explore', 'v')
# ('grow', 'v')
# ('increase', 'v')
# ('occur', 'v')
# ('rely', 'v')
# ('respond', 'v')
# ('state', 'v')
# ('think', 'v')
# ('treat', 'v')
# ('use', 'v')
# ('vary', 'v')
# ('work', 'v')
# v2_adv1 :  79
# ('accept', 'v')
# ('acquire', 'v')
# ('adopt', 'v')
# ('affect', 'v')
# ('agree', 'v')
# ('ally', 'v')
# ('assign', 'v')
# ('associate', 'v')
# ('assume', 'v')
# ('base', 'v')
# ('believe', 'v')
# ('call', 'v')
# ('charge', 'v')
# ('choose', 'v')
# ('cite', 'v')
# ('concern', 'v')
# ('confine', 'v')
# ('connect', 'v')
# ('consider', 'v')
# ('construct', 'v')
# ('control', 'v')
# ('correlate', 'v')
# ('create', 'v')
# ('define', 'v')
# ('demonstrate', 'v')
# ('describe', 'v')
# ('design', 'v')
# ('determine', 'v')
# ('develop', 'v')
# ('disagree', 'v')
# ('discover', 'v')
# ('discuss', 'v')
# ('disperse', 'v')
# ('distribute', 'v')
# ('divide', 'v')
# ('document', 'v')
# ('educate', 'v')
# ('embed', 'v')
# This word doesnt have any collocation type generated! - 7 embed_v_v2_adv1+v-rv
# ('encounter', 'v')
# ('enhance', 'v')
# ('establish', 'v')
# ('evaluate', 'v')
# ('find', 'v')
# ('form', 'v')
# ('identify', 'v')
# ('ignore', 'v')
# ('increase', 'v')
# ('influence', 'v')
# ('inform', 'v')
# ('integrate', 'v')
# ('intend', 'v')
# ('involve', 'v')
# ('know', 'v')
# ('link', 'v')
# ('mention', 'v')
# ('motivate', 'v')
# ('oppose', 'v')
# ('populate', 'v')
# ('read', 'v')
# ('realize', 'v')
# This word doesnt have any collocation type generated! - 7 realize_v_v2_adv1+v-rv
# ('receive', 'v')
# ('recognize', 'v')
# ('reduce', 'v')
# ('refer', 'v')
# ('regard', 'v')
# ('relate', 'v')
# ('remove', 'v')
# ('resemble', 'v')
# ('root', 'v')
# ('select', 'v')
# ('share', 'v')
# ('structure', 'v')
# ('suggest', 'v')
# ('suit', 'v')
# ('think', 'v')
# ('tie', 'v')
# ('understand', 'v')
# ('use', 'v')
# ('value', 'v')
# adj1_n2 :  416
# ('abstract', 'adj')
# ('academic', 'adj')
# ('acceptable', 'adj')
# ('accurate', 'adj')
# ('active', 'adj')
# ('additional', 'adj')
# ('administrative', 'adj')
# ('advanced', 'adj')
# ('adverse', 'adj')
# ('alternative', 'adj')
# ('ample', 'adj')
# ('analytical', 'adj')
# ('anecdotal', 'adj')
# ('annual', 'adj')
# ('appropriate', 'adj')
# ('armed', 'adj')
# ('artificial', 'adj')
# ('associated', 'adj')
# ('atomic', 'adj')
# ('available', 'adj')
# ('average', 'adj')
# ('basic', 'adj')
# ('beneficial', 'adj')
# ('binary', 'adj')
# ('biological', 'adj')
# ('brief', 'adj')
# ('broad', 'adj')
# ('capitalist', 'adj')
# ('careful', 'adj')
# ('causal', 'adj')
# ('central', 'adj')
# ('certain', 'adj')
# ('changing', 'adj')
# ('characteristic', 'adj')
# ('chemical', 'adj')
# ('civil', 'adj')
# ('classic', 'adj')
# ('classical', 'adj')
# ('clear', 'adj')
# ('climatic', 'adj')
# ('close', 'adj')
# ('cognitive', 'adj')
# ('collaborative', 'adj')
# ('collective', 'adj')
# ('combined', 'adj')
# ('commercial', 'adj')
# ('common', 'adj')
# ('comparative', 'adj')
# ('compelling', 'adj')
# ('competitive', 'adj')
# ('complex', 'adj')
# ('comprehensive', 'adj')
# ('conceptual', 'adj')
# ('concerted', 'adj')
# ('concluding', 'adj')
# ('conditional', 'adj')
# ('conflicting', 'adj')
# ('considerable', 'adj')
# ('consistent', 'adj')
# ('constant', 'adj')
# ('constituent', 'adj')
# ('contemporary', 'adj')
# ('contextual', 'adj')
# ('continued', 'adj')
# ('continuous', 'adj')
# ('controversial', 'adj')
# ('conventional', 'adj')
# ('convincing', 'adj')
# ('coping', 'adj')
# This word doesnt have any collocation type generated! - 8 coping_a_adj1_n2+a-an
# ('core', 'adj')
# ('correct', 'adj')
# ('counter', 'adj')
# ('creative', 'adj')
# ('criminal', 'adj')
# ('critical', 'adj')
# ('crucial', 'adj')
# ('cultural', 'adj')
# ('current', 'adj')
# ('daily', 'adj')
# ('deep', 'adj')
# ('defining', 'adj')
# ('deliberate', 'adj')
# ('democratic', 'adj')
# ('demographic', 'adj')
# ('dependent', 'adj')
# ('descriptive', 'adj')
# ('desired', 'adj')
# ('detailed', 'adj')
# ('developmental', 'adj')
# ('diagnostic', 'adj')
# ('digital', 'adj')
# ('direct', 'adj')
# ('disposable', 'adj')
# ('distinct', 'adj')
# ('distinctive', 'adj')
# ('distinguishing', 'adj')
# ('diverse', 'adj')
# ('dividing', 'adj')
# ('documentary', 'adj')
# ('domestic', 'adj')
# ('dominant', 'adj')
# ('dramatic', 'adj')
# ('driving', 'adj')
# This word doesnt have any collocation type generated! - 8 driving_a_adj1_n2+a-an
# ('due', 'adj')
# This word doesnt have any collocation type generated! - 8 due_a_adj1_n2+a-an
# ('dynamic', 'adj')
# ('early', 'adj')
# ('easy', 'adj')
# ('economic', 'adj')
# ('educational', 'adj')
# ('effective', 'adj')
# ('electronic', 'adj')
# ('emotional', 'adj')
# ('empirical', 'adj')
# ('enormous', 'adj')
# ('entire', 'adj')
# ('environmental', 'adj')
# ('equal', 'adj')
# ('essential', 'adj')
# ('established', 'adj')
# ('ethical', 'adj')
# ('ethnic', 'adj')
# ('evolutionary', 'adj')
# ('exceptional', 'adj')
# ('existing', 'adj')
# ('experiential', 'adj')
# ('experimental', 'adj')
# ('explanatory', 'adj')
# ('extended', 'adj')
# ('extensive', 'adj')
# ('external', 'adj')
# ('facial', 'adj')
# ('factual', 'adj')
# ('fair', 'adj')
# ('far', 'adj')
# ('federal', 'adj')
# ('feminist', 'adj')
# ('final', 'adj')
# ('financial', 'adj')
# ('finite', 'adj')
# ('first', 'adj')
# ('flexible', 'adj')
# ('focal', 'adj')
# ('following', 'adj')
# ('foreign', 'adj')
# ('formal', 'adj')
# ('free', 'adj')
# ('full', 'adj')
# ('functional', 'adj')
# ('fundamental', 'adj')
# ('future', 'adj')
# ('general', 'adj')
# ('genetic', 'adj')
# ('geographical', 'adj')
# ('given', 'adj')
# This word doesnt have any collocation type generated! - 8 given_a_adj1_n2+a-an
# ('global', 'adj')
# ('graphical', 'adj')
# ('great', 'adj')
# ('growing', 'adj')
# This word doesnt have any collocation type generated! - 8 growing_a_adj1_n2+a-an
# ('guiding', 'adj')
# This word doesnt have any collocation type generated! - 8 guiding_a_adj1_n2+a-an
# ('heated', 'adj')
# ('hierarchical', 'adj')
# ('high', 'adj')
# ('historical', 'adj')
# ('holistic', 'adj')
# ('homogeneous', 'adj')
# ('huge', 'adj')
# ('human', 'adj')
# ('immediate', 'adj')
# ('imported', 'adj')
# ('improved', 'adj')
# ('increased', 'adj')
# ('increasing', 'adj')
# ('independent', 'adj')
# ('indigenous', 'adj')
# ('individual', 'adj')
# ('industrial', 'adj')
# ('industrialized', 'adj')
# ('infinite', 'adj')
# ('informed', 'adj')
# ('initial', 'adj')
# ('institutional', 'adj')
# ('integral', 'adj')
# ('integrated', 'adj')
# ('intellectual', 'adj')
# ('intensive', 'adj')
# ('interested', 'adj')
# ('internal', 'adj')
# ('international', 'adj')
# ('interpersonal', 'adj')
# ('intimate', 'adj')
# ('intrinsic', 'adj')
# ('introductory', 'adj')
# ('key', 'adj')
# ('large', 'adj')
# ('late', 'adj')
# ('leading', 'adj')
# ('learning', 'adj')
# This word doesnt have any collocation type generated! - 8 learning_a_adj1_n2+a-an
# ('legal', 'adj')
# ('legislative', 'adj')
# ('liberal', 'adj')
# ('lifelong', 'adj')
# ('likely', 'adj')
# ('limited', 'adj')
# ('linear', 'adj')
# ('literal', 'adj')
# ('literary', 'adj')
# ('little', 'adj')
# ('living', 'adj')
# This word doesnt have any collocation type generated! - 8 living_a_adj1_n2+a-an
# ('local', 'adj')
# ('logical', 'adj')
# ('long', 'adj')
# ('longitudinal', 'adj')
# ('low', 'adj')
# ('main', 'adj')
# ('major', 'adj')
# ('male', 'adj')
# ('manual', 'adj')
# ('manufacturing', 'adj')
# This word doesnt have any collocation type generated! - 8 manufacturing_a_adj1_n2+a-an
# ('marked', 'adj')
# ('maximum', 'adj')
# ('mean', 'adj')
# ('meaningful', 'adj')
# ('medical', 'adj')
# ('mental', 'adj')
# ('methodological', 'adj')
# ('metropolitan', 'adj')
# ('middle', 'adj')
# ('migrant', 'adj')
# This word doesnt have any collocation type generated! - 8 migrant_a_adj1_n2+a-an
# ('military', 'adj')
# ('minimum', 'adj')
# ('minor', 'adj')
# ('missing', 'adj')
# ('modern', 'adj')
# ('modified', 'adj')
# ('moral', 'adj')
# ('multiple', 'adj')
# ('municipal', 'adj')
# ('mutual', 'adj')
# ('narrow', 'adj')
# ('national', 'adj')
# ('native', 'adj')
# ('natural', 'adj')
# ('necessary', 'adj')
# ('negative', 'adj')
# ('new', 'adj')
# ('next', 'adj')
# ('normal', 'adj')
# ('notable', 'adj')
# ('nuclear', 'adj')
# ('numerical', 'adj')
# ('numerous', 'adj')
# ('objective', 'adj')
# ('obvious', 'adj')
# ('official', 'adj')
# ('ongoing', 'adj')
# ('online', 'adj')
# ('open', 'adj')
# ('opening', 'adj')
# This word doesnt have any collocation type generated! - 8 opening_a_adj1_n2+a-an
# ('optimal', 'adj')
# ('oral', 'adj')
# ('organising', 'adj')
# This word doesnt have any collocation type generated! - 8 organising_a_adj1_n2+a-an
# ('organizational', 'adj')
# ('original', 'adj')
# ('overall', 'adj')
# ('overwhelming', 'adj')
# ('paid', 'adj')
# This word doesnt have any collocation type generated! - 8 paid_a_adj1_n2+a-an
# ('paramount', 'adj')
# ('particular', 'adj')
# ('past', 'adj')
# ('perceived', 'adj')
# ('personal', 'adj')
# ('physical', 'adj')
# ('pioneering', 'adj')
# This word doesnt have any collocation type generated! - 8 pioneering_a_adj1_n2+a-an
# ('pivotal', 'adj')
# ('plausible', 'adj')
# ('political', 'adj')
# ('popular', 'adj')
# ('positive', 'adj')
# ('possible', 'adj')
# ('potential', 'adj')
# ('powerful', 'adj')
# ('practical', 'adj')
# ('preceding', 'adj')
# This word doesnt have any collocation type generated! - 8 preceding_a_adj1_n2+a-an
# ('precise', 'adj')
# ('predictive', 'adj')
# ('preferential', 'adj')
# ('preliminary', 'adj')
# ('premature', 'adj')
# ('present', 'adj')
# ('presidential', 'adj')
# ('previous', 'adj')
# ('primary', 'adj')
# ('prime', 'adj')
# ('principal', 'adj')
# ('prior', 'adj')
# ('private', 'adj')
# ('privileged', 'adj')
# ('professional', 'adj')
# ('profound', 'adj')
# ('prominent', 'adj')
# ('proposed', 'adj')
# ('public', 'adj')
# ('published', 'adj')
# This word doesnt have any collocation type generated! - 8 published_a_adj1_n2+a-an
# ('purchasing', 'adj')
# This word doesnt have any collocation type generated! - 8 purchasing_a_adj1_n2+a-an
# ('qualitative', 'adj')
# ('quantitative', 'adj')
# ('racial', 'adj')
# ('radical', 'adj')
# ('random', 'adj')
# ('rapid', 'adj')
# ('raw', 'adj')
# ('ready', 'adj')
# ('real', 'adj')
# ('recent', 'adj')
# ('reciprocal', 'adj')
# ('recurrent', 'adj')
# ('reflective', 'adj')
# ('regional', 'adj')
# ('regulatory', 'adj')
# ('related', 'adj')
# ('relative', 'adj')
# ('relevant', 'adj')
# ('reliable', 'adj')
# ('religious', 'adj')
# ('renewable', 'adj')
# ('renewed', 'adj')
# ('representative', 'adj')
# ('revised', 'adj')
# ('rich', 'adj')
# ('rising', 'adj')
# ('ruling', 'adj')
# This word doesnt have any collocation type generated! - 8 ruling_a_adj1_n2+a-an
# ('rural', 'adj')
# ('safe', 'adj')
# ('salient', 'adj')
# ('scarce', 'adj')
# ('schematic', 'adj')
# ('scholarly', 'adj')
# ('scientific', 'adj')
# ('secondary', 'adj')
# ('seminal', 'adj')
# ('senior', 'adj')
# ('separate', 'adj')
# ('serious', 'adj')
# ('sexual', 'adj')
# ('shared', 'adj')
# ('sharp', 'adj')
# ('short', 'adj')
# ('significant', 'adj')
# ('similar', 'adj')
# ('simple', 'adj')
# ('simplified', 'adj')
# ('single', 'adj')
# ('skilled', 'adj')
# ('slow', 'adj')
# ('small', 'adj')
# ('social', 'adj')
# ('socioeconomic', 'adj')
# ('solar', 'adj')
# ('sovereign', 'adj')
# ('special', 'adj')
# ('specific', 'adj')
# ('standard', 'adj')
# ('stark', 'adj')
# ('statistical', 'adj')
# ('strategic', 'adj')
# ('striking', 'adj')
# ('strong', 'adj')
# ('structural', 'adj')
# ('subject', 'adj')
# ('subsequent', 'adj')
# ('substantial', 'adj')
# ('successful', 'adj')
# ('sufficient', 'adj')
# ('superior', 'adj')
# ('supporting', 'adj')
# ('symbiotic', 'adj')
# ('systematic', 'adj')
# ('tacit', 'adj')
# ('technical', 'adj')
# ('technological', 'adj')
# ('textual', 'adj')
# ('thematic', 'adj')
# ('theoretical', 'adj')
# ('third', 'adj')
# ('top', 'adj')
# ('total', 'adj')
# ('traditional', 'adj')
# ('transferable', 'adj')
# ('typical', 'adj')
# ('ultimate', 'adj')
# ('underlying', 'adj')
# ('unequal', 'adj')
# ('unfair', 'adj')
# ('unintended', 'adj')
# ('unique', 'adj')
# ('unlimited', 'adj')
# ('unskilled', 'adj')
# ('urban', 'adj')
# ('useful', 'adj')
# ('valid', 'adj')
# ('valuable', 'adj')
# ('various', 'adj')
# ('varying', 'adj')
# ('vast', 'adj')
# ('verbal', 'adj')
# ('vested', 'adj')
# This word doesnt have any collocation type generated! - 8 vested_a_adj1_n2+a-an
# ('virtual', 'adj')
# ('visual', 'adj')
# ('vital', 'adj')
# ('vulnerable', 'adj')
# ('western', 'adj')
# ('whole', 'adj')
# ('wide', 'adj')
# ('widespread', 'adj')
# ('written', 'adj')
# ('young', 'adj')
# adj2_v1 :  23
# ('apparent', 'adj')
# This word doesnt have any collocation type generated! - 9 apparent_a_adj2_v1+a-vppa
# ('appropriate', 'adj')
# ('available', 'adj')
# This word doesnt have any collocation type generated! - 9 available_a_adj2_v1+a-vppa
# ('aware', 'adj')
# This word doesnt have any collocation type generated! - 9 aware_a_adj2_v1+a-vppa
# ('blurred', 'adj')
# This word doesnt have any collocation type generated! - 9 blurred_a_adj2_v1+a-vppa
# ('constant', 'adj')
# This word doesnt have any collocation type generated! - 9 constant_a_adj2_v1+a-vppa
# ('established', 'adj')
# This word doesnt have any collocation type generated! - 9 established_a_adj2_v1+a-vppa
# ('evident', 'adj')
# This word doesnt have any collocation type generated! - 9 evident_a_adj2_v1+a-vppa
# ('explicit', 'adj')
# This word doesnt have any collocation type generated! - 9 explicit_a_adj2_v1+a-vppa
# ('independent', 'adj')
# ('involved', 'adj')
# This word doesnt have any collocation type generated! - 9 involved_a_adj2_v1+a-vppa
# ('necessary', 'adj')
# ('obvious', 'adj')
# This word doesnt have any collocation type generated! - 9 obvious_a_adj2_v1+a-vppa
# ('plausible', 'adj')
# This word doesnt have any collocation type generated! - 9 plausible_a_adj2_v1+a-vppa
# ('relevant', 'adj')
# ('stable', 'adj')
# This word doesnt have any collocation type generated! - 9 stable_a_adj2_v1+a-vppa
# ('successful', 'adj')
# ('unchanged', 'adj')
# This word doesnt have any collocation type generated! - 9 unchanged_a_adj2_v1+a-vppa
# ('unclear', 'adj')
# This word doesnt have any collocation type generated! - 9 unclear_a_adj2_v1+a-vppa
# ('unlikely', 'adj')
# ('useful', 'adj')
# ('visible', 'adj')
# This word doesnt have any collocation type generated! - 9 visible_a_adj2_v1+a-vppa
# ('widespread', 'adj')
# This word doesnt have any collocation type generated! - 9 widespread_a_adj2_v1+a-vppa
# adj2_adv1 :  73
# ('acceptable', 'adj')
# ('accessible', 'adj')
# ('acute', 'adj')
# ('apparent', 'adj')
# ('appropriate', 'adj')
# ('available', 'adj')
# ('aware', 'adj')
# ('changing', 'adj')
# This word doesnt have any collocation type generated! - 10 changing_a_adj2_adv1+a-ra
# ('clear', 'adj')
# ('common', 'adj')
# ('competitive', 'adj')
# ('complex', 'adj')
# ('constant', 'adj')
# ('controversial', 'adj')
# ('correct', 'adj')
# ('critical', 'adj')
# ('dangerous', 'adj')
# ('dependent', 'adj')
# ('desirable', 'adj')
# ('different', 'adj')
# ('difficult', 'adj')
# ('effective', 'adj')
# ('efficient', 'adj')
# ('emerging', 'adj')
# This word doesnt have any collocation type generated! - 10 emerging_a_adj2_adv1+a-ra
# ('equal', 'adj')
# ('established', 'adj')
# This word doesnt have any collocation type generated! - 10 established_a_adj2_adv1+a-ra
# ('evident', 'adj')
# ('exclusive', 'adj')
# ('few', 'adj')
# ('following', 'adj')
# This word doesnt have any collocation type generated! - 10 following_a_adj2_adv1+a-ra
# ('growing', 'adj')
# This word doesnt have any collocation type generated! - 10 growing_a_adj2_adv1+a-ra
# ('high', 'adj')
# ('identical', 'adj')
# ('important', 'adj')
# ('impossible', 'adj')
# ('increasing', 'adj')
# This word doesnt have any collocation type generated! - 10 increasing_a_adj2_adv1+a-ra
# ('influential', 'adj')
# ('likely', 'adj')
# ('little', 'adj')
# ('low', 'adj')
# ('minor', 'adj')
# ('new', 'adj')
# ('obvious', 'adj')
# ('occurring', 'adj')
# This word doesnt have any collocation type generated! - 10 occurring_a_adj2_adv1+a-ra
# ('popular', 'adj')
# ('powerful', 'adj')
# ('preceding', 'adj')
# This word doesnt have any collocation type generated! - 10 preceding_a_adj2_adv1+a-ra
# ('problematic', 'adj')
# ('proportional', 'adj')
# ('rare', 'adj')
# ('recent', 'adj')
# ('relevant', 'adj')
# ('responsible', 'adj')
# ('selective', 'adj')
# ('sensitive', 'adj')
# ('significant', 'adj')
# ('similar', 'adj')
# ('simple', 'adj')
# ('skilled', 'adj')
# ('sophisticated', 'adj')
# ('specific', 'adj')
# ('stable', 'adj')
# ('straightforward', 'adj')
# ('striking', 'adj')
# ('successful', 'adj')
# ('surprising', 'adj')
# ('true', 'adj')
# ('unlikely', 'adj')
# ('useful', 'adj')
# ('valid', 'adj')
# ('valuable', 'adj')
# ('variable', 'adj')
# ('visible', 'adj')
# 2018-04-26 13:48:57
